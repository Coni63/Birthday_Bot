# %% [markdown]
# # Introduction
#
# Few month ago a youtuber presented a small bot on twitter which tweet everyday, the sum of delayed train in France. This gaves me the idea of wishing a happy birthday to celebrities with a specific account automatically. In this notebook, we will extract birthday and twitter account from a website using web scrapping and store data in a small database to deplay the bot afterward.

# %%
import sqlite3
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
pattern = re.compile("[0-9]+")

# %% [markdown]
# # DB creation
#
# First let's create the SQLite db. It's small, easy to deploy without any installation so perfect for this. We will need 1 table to store :
#
# - name
# - birthday
# - twitter account
# - url on the website we scrap (optionnal but I'll use it for updates)
# - country (for Now I'll send tweet only to French celebrities
# - if the person is dead or not

# %%
# conn = sqlite3.connect('F:/data/birthday.db')
# c = conn.cursor()
# c.execute('''DROP TABLE IF EXISTS birthday''')
# c.execute('''CREATE TABLE birthday
#              (birthday date_text, name text, twitter text, url text, country text, dead integer)''')
# # c.execute("INSERT INTO birthday VALUES ('1990-05-15','Nicolas M.','@Coni631', '', 'France', '0')")
# conn.commit()
# conn.close()

# %% [markdown]
# We can now check if it works.

# %%
# conn = sqlite3.connect('F:/data/birthday.db')
# c = conn.cursor()
# c.execute('SELECT * FROM birthday')
# print(c.fetchone())
# conn.close()

# %% [markdown]
# And it's fine

# %% [markdown]
# # Scapping
#
# For the scrapping, we will use https://anniversaire-celebrite.com/ as a website to scrap the info. First of all, we will go throught every day of the year to gather all persons having a birthday at this date. For each persons, we will open their own page to scrap the account if we have it.To do so let's create few fonctions :

# %%
def check_if_exist(name):
    conn = sqlite3.connect('F:/data/birthday.db')
    c = conn.cursor()
    c.execute("SELECT * FROM birthday WHERE name=?", (name,))
    if c.fetchone() is None:
        res = False
    else:
        res = True
    conn.close()
    return res
    
def get_Twitter(url):
    actor_page = requests.get(url)
    DOM = BeautifulSoup(actor_page.text, "html.parser")
    counter = DOM.find("div", attrs={"class" : "twitter"})
    if counter is not None:
        url = counter.find("a")["href"]
        account = "@" + url.split("/")[-1]
        return account
    return ""

def add_data(birthday, name, twitter, url, country, dead):
    conn = sqlite3.connect('F:/data/birthday.db')
    c = conn.cursor()
    q = "INSERT INTO birthday VALUES ('{}','{}','{}', '{}', '{}', '{}')".format(birthday, name, twitter, url, country, dead)
    c.execute(q)
    conn.commit()
    conn.close()

def page_to_actor(DOM, month, day):
    birthday_block = DOM.find_all("div", attrs={"class":"columns"})[3]
    actors = birthday_block.find_all("div", attrs={"class":"column col-2 col-xl-2 col-lg-3 col-md-4 col-xs-6"})
    for actor in actors:
        data = actor_to_data(actor, month, day)
    
def actor_to_data(actor, month, day):
    result = {}
    alts = actor.find_all("img")
    year_txt = actor.find("div", {"class" : "celannee tiny"}).getText()
    year = int(pattern.search(year_txt).group(0))
    result["name"] = re.sub("'","''", alts[0]['alt'])
    result["country"] = re.sub("'","''", alts[1]['alt'])
    result["birthday"] = "{}-{:02d}-{:02d}".format(year, month, day)
    result["dead"] = len(actor.find("div", {"class" : "celage"}).find_all("strong")) - 1
    result["url"] = "https://anniversaire-celebrite.com/" + actor.find("a")["href"]
    
    alread_in = check_if_exist(result["name"])
    if not alread_in:
        if result["dead"] == 0:
            result["twitter"] = get_Twitter(result["url"])
        else:
            result["twitter"] = ""
        add_data(**result)
    else:
        print("Skip " + result["name"])

# %% [markdown]
# Now we just have to run it for all date of the year

# %%
done = True
for month in range(1, 13):
    for day in range(1, 32):
        if month == 1 and day == 10:
            done = False
            
        if not done:
            print("extracting {:02d}/{:02d}".format(day, month))
            url = "https://anniversaire-celebrite.com/ok,annee,{:02d},{:02d}.html".format(month, day)
            page = requests.get(url)
            soup = BeautifulSoup(page.text, "html.parser")
            page_to_actor(soup, month, day)

# %% [markdown]
# # Add new persons
#
# Sometimes, the website add celebrities to their website, we can create a small function to check it and store new ones.

# %%
def getDataFromProfil(url):
    actor_page = requests.get(url)
    DOM = BeautifulSoup(actor_page.text, "html.parser")
    birthday = DOM.find(itemprop="birthDate")["datetime"]
    dead = 1 if DOM.find(itemprop="deathDate") else 0
    counter = DOM.find("div", attrs={"class" : "twitter"})
    if counter is not None:
        url = counter.find("a")["href"]
        account = "@" + url.split("/")[-1]
        return birthday, account, dead
    return birthday, "", dead

# %%
url = "https://anniversaire-celebrite.com/last.html?tri=4" #[1 = homme, 2 femme, 3 mort, 4 vivant]
page = requests.get(url)
DOM = BeautifulSoup(page.text, "html.parser")
birthday_block = DOM.find_all("div", attrs={"class":"columns"})[3]
actors = birthday_block.find_all("div", attrs={"class":"column col-2 col-xl-2 col-lg-3 col-md-4 col-xs-6"})
for actor in actors:
    result = {}
    alts = actor.find_all("img")
    year_txt = actor.find("div", {"class" : "celannee tiny"}).getText()
    year = int(pattern.search(year_txt).group(0))
    result["name"] = re.sub("'","''", alts[0]['alt'])
    result["country"] = re.sub("'","''", alts[1]['alt'])
    result["url"] = "https://anniversaire-celebrite.com/" + actor.find("a")["href"]
    
    alread_in = check_if_exist(result["name"])
    if not alread_in:
        birthday, twitter, dead = getDataFromProfil(result["url"])
        result["twitter"] = twitter
        result["birthday"] = birthday
        result["dead"] = dead
        print("Add " + result["name"])
        add_data(**result)
    else:
        print("Skip " + result["name"])
# Out:
# Skip Yves Pignot
# Skip Robbie Coltrane
# Skip  Sananas
# Skip Benjamin Pavard
# Skip Vicky Leandros
# Skip Mary Steenburgen
# Skip Markus Persson
# Skip Catherine Alric
# Skip Lizzie Brocheré
# Skip Peter Bogdanovich
# Add Ryan O''Neal
# Skip  Lord Vinheteiro
# Skip  Jiminy Cricket
# Skip  Fée Clochette
# Skip John Boyega
# Skip James Dyson
# Skip Franck Provost
# Skip Jane March
# Skip Luc Thuillier
# Skip  Le Petit Chaperon rouge
# Skip  Blanche-Neige
# Skip Roger Rabbit
# Skip Sam le pirate
# Skip  Speedy Gonzales
# Skip Alice Belaïdi
# Add  E.T., l''extra-terrestre
# Skip Angelo Branduardi
# Skip François-Éric Gendron
# Skip  Valli
# Skip John Hannah
# Skip Benoît Brisefer
# Skip Ritchie Blackmore
# Skip Roger Glover
# Skip Derren Brown
# Skip  Yoda
# Skip  Heidi
# Skip Harold Faltermeyer
# Skip Paul Le Guen
# Skip Pascale Petit
# Skip Sandie Shaw
# Skip Bernard Minet
# Add  L''Élève Ducobu
# Skip  Bill
# Skip  Boule
# Skip Mohamed Salah
# Skip Luis Suárez
# Skip Yoann Sover
# Skip Caroline Munoz
# Skip Elle Fanning
# Skip Greta Thunberg
# Skip Jeri Ryan
# Skip Christopher Atkins
# Skip Eugénie Le Sommer
# Skip Amandine Henry
# Skip Molly Ringwald
# Skip Nicolas Vanier
# Skip Lou Diamond Phillips
# Skip Pascal Nzonzi
# Skip Medi Sadoun
# Skip Judge Reinhold
# Skip  6ix9ine
# Skip Bella Hadid
# Skip  E. L. James
# Skip Camila Cabello
# Skip Mini Anden
# Skip Alexandre Sterling
# Skip  Kheiron
# Skip Joe Don Baker
# Add Serge Khalfon
# Skip Maud Adams
# Add  Marshmello
# Add Linus Torvalds
# Add Olivier Nakache
# Skip Anne Décis
# Add Marco Verratti
# Add Ángel Di María
# Add François Pirette
# Add Edinson Cavani
# Add Gianluigi Buffon
# Skip Tatiana Silva
# Skip Barbara Pompili
# Add Víctor Pecci
# Add Denis Baupin
# Add Franck Capillery

# %% [markdown]
# # Check Profil for update
#
# Another thing to consider is the case where there is changes. For example, we have several celebrities without twitter account. We could also create a function to check all celebrities without official twitter regularly (that's why I saved the url) and add the account if it's added. Some people may also die and we should not wish them a Happy Birthday :(

# %%
conn = sqlite3.connect('F:/data/birthday.db')
c = conn.cursor()
c.execute("SELECT name, url FROM birthday WHERE twitter = '' AND dead == 0")
l = c.fetchall()
conn.close()

# %%
# skip = True
for name, url in l:
#     if name == "Paul-henri Mathieu":
#         skip = False
#     if not skip:
    print("Checking", name)
    birthday, twitter, dead = getDataFromProfil(url)
    if twitter != "" or dead == 1:
        print("Update on", name)
        conn = sqlite3.connect('F:/data/birthday.db')
        c = conn.cursor()
        c.execute("UPDATE birthday SET twitter = ?, dead = ? WHERE name = ?", (twitter, dead, name))
        conn.commit()
        conn.close()
# Out:
# Checking Paul-henri Mathieu
# Update on Paul-henri Mathieu
# Checking Olivier Martinez
# Checking John Lasseter
# Checking Charlotte Julian
# Checking Jean-Louis Bianco
# Checking  Jordy
# Checking Christine Lemler
# Checking Emily Watson
# Checking Steven Soderbergh
# Checking Stéphane Thebaut
# Checking Dominique Rocheteau
# Checking Jean-François Mattéi
# Checking Faye Dunaway
# Checking Kellita Smith
# Checking Frédéric Lordon
# Checking  Yellowman
# Checking Catherine Trautmann
# Checking Marius Trésor
# Checking Richard Bohringer
# Checking Jean-Claude Narcy
# Checking Naveen Andrews
# Checking Mathilde Seigner
# Checking Mick Taylor
# Checking Françoise Hardy
# Checking Alison Arngrim
# Checking Philippe Starck
# Checking Franz-Olivier Giesbert
# Checking Stefan Edberg
# Checking Tippi Hedren
# Checking Skeet Ulrich
# Checking James Denton
# Checking Gérard Hernandez
# Checking Buzz Aldrin
# Checking Vanessa Hessler
# Checking Nicolas Mahut
# Checking Philippe Lelièvre
# Checking Geena Davis
# Checking  Bigflo
# Checking Raica Oliveira
# Checking Frank Leboeuf
# Checking Diane Lane
# Checking Joséphine de Meaux
# Checking Léa Drucker
# Checking Claude Perron
# Checking Didier Bourdon
# Checking Laurent Boyer
# Checking Éric Métayer
# Checking Caroline de Monaco
# Checking Rutger Hauer
# Checking Maurice Bénichou
# Checking Laure Belleville
# Checking Carole Merle
# Checking Muriel Moreno
# Checking Nastassja Kinski
# Checking Raymond Domenech
# Checking Daniel Auteuil
# Checking Marie-Pierre Casey
# Checking Hafsia Herzi
# Checking Charlene Wittstock
# Checking Florence Geanty
# Checking Pascal Bataille
# Checking Marie-Paule Belle
# Checking Maurice Risch
# Checking Melvil Poupaud
# Checking Jean-Paul Rouve
# Checking Michel Sardou
# Checking Marat Safin
# Checking Rosamund Pike
# Checking Michel Guidoni
# Checking Bridget Fonda
# Checking Édith Cresson
# Checking Michael Jones
# Checking Marthe Keller
# Checking John Beck
# Checking Carlos Slim Helú
# Checking Julia Piaton
# Checking Tania Bruna-Rosso
# Checking Riton Liebman
# Checking Dalila Di Lazzaro
# Checking Marc Singer
# Checking Tom Selleck
# Checking Katharine Ross
# Checking Françoise Brion
# Checking Felipe VI
# Checking  Abdallah II
# Checking Dick Cheney
# Checking Jean Tiberi
# Checking Gene Hackman
# Checking Ary Abittan
# Checking John Lydon
# Checking Jonathan Banks
# Checking Daniela Bianchi
# Checking  Beatrix
# Checking Philip Glass
# Checking Michael C. Hall
# Checking Stéphanie de Monaco
# Checking Sherilyn Fenn
# Checking Manuel Amoros
# Checking Tony Leung Ka-fai
# Checking Jean Roucas
# Checking Jean-Marie Périer
# Checking Gemma Arterton
# Checking Jeanne Savary
# Checking Marie-Claude Pietragalla
# Checking Phil Barney
# Checking Bernard Farcy
# Checking Valéry Giscard d'Estaing
# Checking Vincent Elbaz
# Checking Maura Tierney
# Checking Paul Auster
# Checking  Leslie
# Checking William Leymergie
# Checking Jean-Jacques Moreau
# Checking Julien Donzé
# Checking Olivia Adriaco
# Checking Laura Linney
# Checking Dominique Besnehard
# Checking Laurent Broomhead
# Checking Tom Wilkinson
# Checking Charlotte Rampling
# Checking Michael Mann
# Checking Claude Giraud
# Checking Victor Webster
# Checking Emmanuel Curtil
# Checking Christine Angot
# Checking Gérard Blanchard
# Checking Juliette Gréco
# Checking Guy-Manuel de Homem-Christo
# Checking Marc Andréoni
# Checking Niels Arestrup
# Checking Nick Nolte
# Checking John Williams
# Checking David Gallagher
# Checking Mena Suvari
# Checking Guy Lagache
# Checking Gérard Lenorman
# Checking Joe Pesci
# Checking Maxime Le Forestier
# Checking Brice Lalonde
# Checking Robert Wagner
# Checking Alexandra Neldel
# Checking Laurence Côte
# Checking Carey Lowell
# Checking Joëlle Sevilla
# Checking Antoine Waechter
# Checking Marc Menant
# Checking Jacques Pradel
# Checking Mary Quant
# Checking Daphné Roulier
# Checking Josh Brolin
# Checking Corinne Benizio
# Checking  Voutch
# Checking Michael Ironside
# Checking Pierrette Brès
# Checking  Costa-Gavras
# Checking Mayra Andrade
# Checking Valéry Zeitoun
# Checking Albert Kassabi
# Checking Beate Klarsfeld
# Checking George Segal
# Checking Emanuel Ungaro
# Checking Kim Novak
# Checking Paul Biya
# Checking Freddie Highmore
# Checking Anne-Gaëlle Riccio
# Checking Raphaëlle Ricci
# Checking Marie-Sophie L.
# Checking Catherine Arditi
# Checking Alan Parker
# Checking Roland Giraud
# Checking Dorothée Pousséo
# Checking Axelle Red
# Checking Santiago Amigorena
# Checking Patrick Montel
# Checking Jane Seymour
# Checking Émile Wandelmer
# Checking Marisa Berenson
# Checking Matthieu Ricard
# Checking Georgette Lemaire
# Checking John McEnroe
# Checking Richard Ford
# Checking Georgina Dufoix
# Checking Kelly Carlson
# Checking Jerry O'Connell
# Checking Michael Jordan
# Checking Rene Russo
# Checking André Dussollier
# Checking Hal Holbrook
# Checking Laure Marsac
# Checking Christophe Guybet
# Checking John Travolta
# Checking Jean-Claude Dreyfus
# Checking Cybill Shepherd
# Checking Yoko Ono
# Checking Benicio del Toro
# Checking Rika Zaraï
# Checking Jean-Baptiste Shelmerdine
# Checking  Gringe
# Checking Lauren Ambrose
# Checking Laure Guibert
# Checking Andrew Shue
# Checking Gordon Brown
# Checking Ivana Trump
# Checking Peter Strauss
# Checking Richard Cocciante
# Checking Sidney Poitier
# Checking William Baldwin
# Checking Laurent Petitguillaume
# Checking Jean-Jacques Peroni
# Checking Tyne Daly
# Checking  Harald V
# Checking Robert Mugabe
# Checking Armelle Deutsch
# Checking Michael Chang
# Checking  Miou-Miou
# Checking Niki Lauda
# Checking Dakota Fanning
# Checking Kelly Macdonald
# Checking Marie-Josée Croze
# Checking Carole Gaessler
# Checking Hélène Darroze
# Checking Louis Bertignac
# Checking Philippe Chatel
# Checking Peter Fonda
# Checking Jacques Séguéla
# Checking Alessandro Gassmann
# Checking Mark Moses
# Checking Gérard Longuet
# Checking Philip Knight
# Checking Michel Legrand
# Update on Michel Legrand
# Checking Hélène de Fougerolles
# Checking Sandrine Kiberlain
# Checking Régis Laspalès
# Checking Herbert Léonard
# Checking Karen Grassle
# Checking Valérie Lagrange
# Checking Romane Serda
# Checking Emmanuel Levy
# Checking Michel Houellebecq
# Checking Recep Tayyip Erdogan
# Checking Jean Teulé
# Checking François Perrot
# Update on François Perrot
# Checking Asami Abe
# Checking Alix Poisson
# Checking Julie Andrieu
# Checking Didier Super
# Checking Maggie Siu
# Checking Timothy Spall
# Checking Yolande Moreau
# Checking Féodor Atkine
# Checking Joanne Woodward
# Checking Cali Morales
# Checking Robert Sean Leonard
# Checking Gavin MacLeod
# Checking Frank Gehry
# Checking Laurent Louis
# Checking  Khaled
# Checking Gérard Darmon
# Checking Robinson Stévenin
# Checking Mark-Paul Gosselaar
# Checking  Bambou
# Checking Catherine Bach
# Checking Jacques Mailhot
# Checking Lana Wood
# Checking Dirk Benedict
# Checking Pierre Bénichou
# Checking Robert Conrad
# Checking Philippe Tesson
# Checking Chris Martin
# Checking Valérie Donzelli
# Checking Daniel Craig
# Checking Christian Morin
# Checking Luc Plamondon
# Checking Abdelaziz Bouteflika
# Checking Mikhaïl Gorbatchev
# Checking Lannick Gautry
# Checking Charles-Philippe d'Orléans
# Checking Victoria Zdrok
# Checking Julie Bowen
# Checking Jean-Paul Farré
# Checking Andrea Bowen
# Checking Jean-Christophe Hembert
# Checking Thierry Pastor
# Checking Dominique Pinon
# Checking Nicole Calfan
# Checking Serge Papagalli
# Checking Shirley Bousquet
# Checking Bertrand Cantat
# Checking Catherine Matausch
# Checking Bernard Arnault
# Checking Lova Moor
# Checking Murray Head
# Checking Élisabeth Badinter
# Checking Dean Stockwell
# Checking Juliette Arnaud
# Checking François Bachy
# Checking Harald Schumacher
# Checking Guy Montagné
# Checking Patrick Baudry
# Checking Valentina Terechkova
# Checking Marie-France Garaud
# Checking Jang Dong-gun
# Checking Rachel Weisz
# Checking Jenna de Rosnay
# Checking Ivan Lendl
# Checking Corine Marienneau
# Checking Danyel Gérard
# Checking Estelle Desanges
# Checking Pierre-Emmanuel Barré
# Checking Rona Hartner
# Checking Marianne Basler
# Checking Valérie Lemercier
# Checking Linda Fiorentino
# Checking Carlos Ghosn
# Checking Ornella Muti
# Checking Henry-Jean Servat
# Checking Jean-Jacques Debout
# Checking Olivia Wilde
# Checking Eva Herzigová
# Checking Didier Barbelivien
# Checking Alex Kingston
# Checking Aaron Eckhart
# Checking Patrick Battiston
# Checking Didier Flamand
# Checking Liza Minnelli
# Checking  Yuya
# Checking Lucie Jeanne
# Checking Jean-Yves Lafesse
# Checking Renaud Donnedieu de Vabres
# Checking André Téchiné
# Checking Ève Ruggiéri
# Checking Nicolas Anelka
# Checking Sylvie Noachovitch
# Checking Patrick Dupond
# Checking Albert de Monaco
# Checking Steve Kanaly
# Checking Bertrand Blier
# Checking Yves Boisset
# Checking Michael Caine
# Checking Philippe Alexandre
# Checking Terence Trent D'Arby
# Checking Julie Bataille
# Checking Joaquim de Almeida
# Checking Jacques Doillon
# Checking David Cronenberg
# Checking Anne Charrier
# Checking Cristiana Reali
# Checking Isabelle Huppert
# Checking Erik Estrada
# Checking Victor Garber
# Checking Jean-Claude Dauphin
# Checking Guesch Patti
# Checking Marc Meneau
# Checking Kurt Russell
# Checking Daniel Lavoie
# Checking Anne Girouard
# Checking Marine Delterme
# Checking Vanessa Lynn Williams
# Checking Arnaud Lagardère
# Checking Xavier Deluc
# Checking Jacques Secrétin
# Checking Patrick Chesnais
# Checking Arlette Laguiller
# Checking Ivan Levaï
# Checking Kim Rae-won
# Checking Rachel Blanchard
# Checking Mallaury Nataf
# Checking Bruce Willis
# Checking Harvey Weinstein
# Checking Ursula Andress
# Checking  Ruby Rose
# Checking Anouk Grinberg
# Checking Holly Hunter
# Checking Spike Lee
# Checking Élizabeth Bourgine
# Checking William Hurt
# Checking Danièle Gilbert
# Checking Marthe Villalonga
# Checking Cannelle Carré-Cassaigne
# Checking Abdel En Vrai
# Checking Pauline Lefèvre
# Checking Valérie Pascal
# Checking Matthew Broderick
# Checking Gary Oldman
# Checking Christophe Malavoy
# Checking Timothy Dalton
# Checking Marie-Christine Barrault
# Checking Dirk Frimout
# Checking Christian Charmetant
# Checking Lena Olin
# Checking Fanny Ardant
# Checking Erik Orsenna
# Checking George Benson
# Checking Bruno Ganz
# Checking Michel Hidalgo
# Checking Judith Godrèche
# Checking Pierre Palmade
# Checking Élisabeth Quin
# Checking José Manuel Durão Barroso
# Checking Michel Crémadès
# Checking Albert Algoud
# Checking Chantal Lauby
# Checking Christophe Dugarry
# Checking Peter Jacobson
# Checking  Nena
# Checking Sophie Barjac
# Checking Jean-Christophe Bouvet
# Checking Romain Bouteille
# Checking Jean-Louis David
# Checking  Alem
# Checking Wladimir Klitschko
# Checking Bernard de La Villardière
# Checking Paul Michael Glaser
# Checking Daniel Buren
# Checking Larry Page
# Checking Michael Imperioli
# Checking Julie Jézéquel
# Checking Roch Voisine
# Checking François Léotard
# Checking James Caan
# Checking Mahmoud Abbas
# Checking Charles Dumont
# Checking  Didi Chandouidoui
# Checking Grégori Derangère
# Checking Elizabeth Mitchell
# Checking Quentin Tarantino
# Checking Michael York
# Checking Claire Maurier
# Checking Aurore Auteuil
# Checking Vince Vaughn
# Checking Bernard Darniche
# Checking Christophe Lambert
# Checking Dianne Kay
# Checking Mory Kanté
# Checking  Vangelis
# Checking John Major
# Checking Eric Idle
# Checking Terence Hill
# Checking Ian Ziering
# Checking Warren Beatty
# Checking Robert Badinter
# Checking Joelle Kayembe
# Checking Cindy Sander
# Checking Mélanie Coste
# Checking Delphine de Turckheim
# Checking Yann Moix
# Checking Angus Young
# Checking Christopher Walken
# Checking Claude Allègre
# Checking Richard Chamberlain
# Checking Kris Marshall
# Checking Arnaud Boetsch
# Checking Atmen Kelif
# Checking Luq Hamet
# Checking Philippe Martinez
# Checking Barry Sonnenfeld
# Checking Vincent Bolloré
# Checking Annette O'Toole
# Checking Jimmy Cliff
# Checking Ali MacGraw
# Checking Marcel Amont
# Checking Milan Kundera
# Checking Valérie Expert
# Checking Marie-Ange Nardi
# Checking Michel Troisgros
# Checking Linda Hunt
# Checking Blanche Gardin
# Checking Clotilde Courau
# Checking Eddie Murphy
# Checking Marisa Paredes
# Checking Dominique Paturel
# Checking Doris Day
# Checking Sophie Edelstein
# Checking Frédéric Lopez
# Checking Bernard Campan
# Checking Annie Grégorio
# Checking Bruno Mégret
# Checking Jacques Frantz
# Checking Craig T. Nelson
# Checking Tina Kunakey
# Checking Satoshi Nakamoto
# Checking Élodie Bouchez
# Checking Valérie Bonneton
# Checking Charlotte de Turckheim
# Checking Anne-Marie Périer
# Checking Colin Powell
# Checking Zach Braff
# Checking Paul Rudd
# Checking Frank Black
# Checking Patrick Hernandez
# Checking Roy Thinnes
# Checking Tina S
# Checking Bernard Lama
# Checking Michèle Torr
# Checking Gerhard Schröder
# Checking Francis Ford Coppola
# Checking Évelyne Grandjean
# Checking Patrick Mille
# Checking Alexandre Debanne
# Checking John Schneider
# Checking Christine Boisson
# Checking Jean Benguigui
# Checking Jean-Paul Rappeneau
# Checking Marine Vacth
# Checking Lorella Cravotta
# Checking Dennis Quaid
# Checking Jean-Paul Belmondo
# Checking David Brécourt
# Checking Ged Marlon
# Checking Daniel Bilalian
# Checking Gilles de Robien
# Checking Garance Clavel
# Checking Élise Larnicol
# Checking  Nicoletta
# Checking Nelly Kaplan
# Checking Henri Garcin
# Checking Grégoire Bonnet
# Checking Yuri Buenaventura
# Checking Andy García
# Checking Jean-Pierre Marielle
# Checking Franck Esposito
# Checking Rick Schroder
# Checking Jeanne Balibar
# Checking Garry Kasparov
# Checking Brigitte Macron
# Checking  J. M. G. Le Clézio
# Checking Paul Sorvino
# Checking Anthony Michael Hall
# Checking Robert Carlyle
# Checking Frédéric Courant
# Checking Frank Serpico
# Checking Philippe Lucas
# Checking Philippe de Belgique
# Checking Emma Thompson
# Checking Patrick Adler
# Checking Isabelle de Botton
# Checking Josiane Balasko
# Checking Jango Edwards
# Checking Alain Minc
# Checking Claudia Cardinale
# Checking Raymond Poulidor
# Checking Jules Sitruk
# Checking Lukas Haas
# Checking  Tex
# Checking Michel Blanc
# Checking Catherine Allégret
# Checking Vivienne Westwood
# Checking  Benoît XVI
# Checking  Maïwenn
# Checking Jennifer Garner
# Checking Pascale Arbillot
# Checking Sean Bean
# Checking Zinedine Soualem
# Checking Afrika Bambaataa
# Checking Gérard Schivardi
# Checking Claire Bretécher
# Checking Rémy Julienne
# Checking Francky Vincent
# Checking John James
# Checking Jean-François Balmer
# Checking Nadine de Rothschild
# Checking  Oli
# Checking Hayden Christensen
# Checking Kate Hudson
# Checking James Franco
# Checking Natalie Dessay
# Checking Paloma Picasso
# Checking Évelyne Dhéliat
# Checking Tim Curry
# Checking Fernando Botero
# Checking Alela Diane
# Checking Omar Harfouch
# Checking Éric Dupond-Moretti
# Checking Jessica Lange
# Checking Michael Brandon
# Checking Robert Smith
# Checking Iggy Pop
# Checking Élisabeth II
# Checking Denis Podalydès
# Checking Évelyne Bouix
# Checking François Berléand
# Checking Nicole Garcia
# Checking Sophie Garel
# Checking Marie-Josée Nat
# Checking Jack Nicholson
# Checking Dev Patel
# Checking Paul Belmondo
# Checking Michel Leeb
# Checking Jean-François Stévenin
# Checking Lee Majors
# Checking Jasmine Trinca
# Checking Stephen Wiltshire
# Checking Dick Rivers
# Checking Christine Ockrent
# Checking Shirley MacLaine
# Checking Renée Zellweger
# Checking Vincent Counard
# Checking Fadela Amara
# Checking Philippine Leroy-Beaulieu
# Checking Dominique Blanc
# Checking Dominique Strauss-Kahn
# Checking Talia Shire
# Checking Björn Ulvaeus
# Checking Bertrand Tavernier
# Checking Al Pacino
# Checking Albert Uderzo
# Checking Anna Mouglalis
# Checking Sébastien Folin
# Checking Didier Gustin
# Checking Claudine Auger
# Checking Ieoh Ming Pei
# Checking Lou de Laâge
# Checking Anne-Charlotte Pontabry
# Checking Ari Vatanen
# Checking Ludmila Mikaël
# Checking Anouk Aimée
# Checking Penélope Cruz
# Checking Jorge Garcia
# Checking Gabrielle Lazure
# Checking Bertrand Renard
# Checking Jacques Dutronc
# Checking Gérard Majax
# Checking Uma Thurman
# Checking Kolinda Grabar-Kitarović
# Checking Michel Bussi
# Checking Michelle Pfeiffer
# Checking  Zouc
# Checking André Wilms
# Checking Robert Namias
# Checking Bernard Madoff
# Checking  Zizi Jeanmaire
# Checking Jane Campion
# Checking António Guterres
# Checking  Jacky
# Checking Burt Young
# Checking Amira Casar
# Checking Wes Anderson
# Checking Catherine Frot
# Checking Douglas Barr
# Checking John Woo
# Checking France Rumilly
# Checking Lily Allen
# Checking David Beckham
# Checking Bruno Le Roux
# Checking Éric Elmosnino
# Checking David Suchet
# Checking Paul Lederman
# Checking Hervé Bourges
# Checking Édouard Balladur
# Checking Christophe Rippert
# Checking Frédéric Bouraly
# Checking Martin Bouygues
# Checking Arièle Semenoff
# Checking Yves Simon
# Checking Sheila O'Connor
# Checking Gérard Jugnot
# Checking Richard Jenkins
# Checking Yves Lecoq
# Checking  Dave
# Checking Hosni Moubarak
# Checking Virginie Efira
# Checking Éric Laugérias
# Checking Élisa Servier
# Checking Melinda Culea
# Checking Michael Palin
# Checking Lance Henriksen
# Checking Bernard Pivot
# Checking Lucien Jean-Baptiste
# Checking George Clooney
# Checking Anne Parillaud
# Checking Tony Blair
# Checking Christian Clavier
# Checking Thérèse Liotard
# Checking Marc Dudicourt
# Checking Zoé Félix
# Checking Véronique Jannot
# Checking Sylvain Augier
# Checking Marie-George Buffet
# Checking Nicolas Rey
# Checking Melissa Gilbert
# Checking Marie Myriam
# Checking David Keith
# Checking Isabelle Alonso
# Checking Catherine Laborde
# Checking Katia Tchenko
# Checking Keith Jarrett
# Checking Dave Gahan
# Checking John Corbett
# Checking Béatrice Schönberg
# Checking Candice Bergen
# Checking Ion Țiriac
# Checking Sylvain Wiltord
# Checking Élodie Hesme
# Checking Linda Evangelista
# Checking Emmanuelle Devos
# Checking Bruno Wolkowitch
# Checking  Bono
# Checking Bruno Madinier
# Checking Laurent Spielvogel
# Checking Marina Vlady
# Checking Jean Becker
# Checking Françoise Fabian
# Checking Armel Le Cléac'h
# Checking Annelise Hesme
# Checking Benoît Magimel
# Checking Thomas Hugues
# Checking Emmanuelle Haïm
# Checking Isabelle Mergault
# Checking Jean-François Dérec
# Checking Fanny Cottençon
# Checking Corinne Lepage
# Checking  Ringo
# Checking Jean Sarrus
# Checking Domhnall Gleeson
# Checking Malin Åkerman
# Checking Sami Bouajila
# Checking Stephen Baldwin
# Checking Emilio Estevez
# Checking Ving Rhames
# Checking Kim Greist
# Checking Olivier Lejeune
# Checking Bruce Boxleitner
# Checking Gabriel Byrne
# Checking Michel Fugain
# Checking Claudie Haigneré
# Checking Stevie Wonder
# Checking Laurent Cabrol
# Checking Senta Berger
# Checking Harvey Keitel
# Checking Anna Gaylor
# Checking Gérard Mulliez
# Checking Mark Zuckerberg
# Checking Caroline Roux
# Checking Sofia Coppola
# Checking Alain Bouzigues
# Checking Marianne Denicourt
# Checking Danny Huston
# Checking Tim Roth
# Checking Michel Cymes
# Checking Robert Zemeckis
# Checking George Lucas
# Checking Lisette Malidor
# Checking Zara Phillips
# Checking David Krumholtz
# Checking David Charvet
# Checking Lee Horsley
# Checking Mike Oldfield
# Checking Vahid Halilhodzic
# Checking Brian Eno
# Checking Billy Crawford
# Checking Judith Henry
# Checking Samuel Labarthe
# Checking Christian Lacroix
# Checking Francis Kuntz
# Checking Gérard Krawczyk
# Checking Jacques Ciron
# Checking Vanessa Guedj
# Checking Jack Johnson
# Checking Helena Noguerra
# Checking  Sandra
# Checking Christiane Jean
# Checking Chow Yun-fat
# Checking  Popeck
# Checking Bernadette Chirac
# Checking Bérénice Marlohe
# Checking Ariel Wizman
# Checking Michel Noir
# Checking James Fox
# Checking Christopher Froome
# Checking Claire Nebout
# Checking Armande Altaï
# Checking Stéphane Collaro
# Checking Fairuza Balk
# Checking Antoine de Maximy
# Checking Éric Carrière
# Checking  Mister T.
# Checking Marc Cerrone
# Checking Ghislaine Ottenheimer
# Checking  Arno
# Checking Robert Castel
# Checking Anna Belknap
# Checking Guy Marchand
# Checking Monique Tarbès
# Checking Alexandre Devoise
# Checking Michel-Édouard Leclerc
# Checking Anatoli Karpov
# Checking Myriam Boyer
# Checking Joan Collins
# Checking kareen Antonn
# Checking  Rose
# Checking Bruno Putzulu
# Checking Éric Cantona
# Checking John C. Reilly
# Checking Fiona Gélin
# Checking Kristin Scott Thomas
# Checking Jean-Pierre Bacri
# Checking Jackie Berroyer
# Checking Dominique Lavanant
# Checking Bob Dylan
# Checking Michael Lonsdale
# Checking Barbara Schulz
# Checking Mike Myers
# Checking Klaus Meine
# Checking Francis Mer
# Checking Pierre Vernier
# Checking Julien Boisselier
# Checking Helena Bonham Carter
# Checking Mehdi El Glaoui
# Checking Francis Zégut
# Checking Dayle Haddon
# Checking Philip Michael Thomas
# Checking Pam Grier
# Checking Lily-Rose Depp
# Checking Laurent Stocker
# Checking Joseph Fiennes
# Checking Laurence Ostolaza
# Checking Alain Souchon
# Checking Henry Kissinger
# Checking Gaël Leforestier
# Checking Romain Duris
# Checking Chiara Mastroianni
# Checking Isabelle Carré
# Checking Péri Cochin
# Checking François-Henri Pinault
# Checking Jean-Pierre Léaud
# Checking Jean-Paul Rouland
# Checking Alysson Paradis
# Checking Sébastien Grosjean
# Checking  Stanislas
# Checking Rupert Everett
# Checking Adrian Paul
# Checking Annette Bening
# Checking Ted Levine
# Checking Catherine Lara
# Checking Helmut Berger
# Checking Peter Higgs
# Checking Louis Velle
# Checking Cécile Auclert
# Checking Colm Meaney
# Checking Luis Rego
# Checking Agnès Varda
# Checking Colin Farrell
# Checking Emmanuelle Bach
# Checking Sandrine Bonnaire
# Checking Laurent Bazin
# Checking Roma Maffia
# Checking François Rollin
# Checking Tom Berenger
# Checking Gregory Harrison
# Checking Soizic Corne
# Checking Alain Duhamel
# Checking Clint Eastwood
# Checking Sarah Marshall
# Checking Davy Sardou
# Checking Sarah Wayne Callies
# Checking Nicolas Gabion
# Checking Karen Mulder
# Checking Catherine Hosmalin
# Checking Fabienne Amiach
# Checking Gilles Benizio
# Checking Ronnie Wood
# Checking Jonathan Pryce
# Checking Claire Nadeau
# Checking Morgan Freeman
# Checking Huguette Bouchardeau
# Checking Wentworth Miller
# Checking  B-Real
# Checking Pierre Dhostel
# Checking Martin Lamotte
# Checking Stacy Keach
# Checking Charlie Watts
# Checking  Maïté
# Checking Claude Véga
# Checking Philippe Djian
# Checking Évelyne Buyle
# Checking Michel Robbe
# Checking Jean-Paul Muel
# Checking Raúl Castro
# Checking  Lucky Blue Smith
# Checking Angelina Jolie
# Checking Joseph Kabila
# Checking Noah Wyle
# Checking Izabella Scorupco
# Checking  Antoine
# Checking Patrick Préjean
# Checking Bruce Dern
# Checking Cécilia Cara
# Checking Élisabeth Buffet
# Checking Astrid de Belgique
# Checking Isabelle Martinet
# Checking Jean-Roger Milo
# Checking Guy Carlier
# Checking  Faudel
# Checking  Małgosia Bela
# Checking Thomas Cousseau
# Checking Paul Giamatti
# Checking Robert Englund
# Checking Albert II
# Checking Anna Kournikova
# Checking Jean-Pierre François
# Checking Thierry Hazard
# Checking Mike Pence
# Checking Johnny Clegg
# Checking Liam Neeson
# Checking Hubert Auriol
# Checking Patrick Le Lay
# Checking Tom Jones
# Checking Frédérique Hébrard
# Checking Julianna Margulies
# Checking Agnès Soral
# Checking Valérie Mairesse
# Checking Kathy Baker
# Checking James Darren
# Checking Maurice Barrier
# Checking Natalie Portman
# Checking Magalie Madison
# Checking Jean Galfione
# Checking Gloria Reuben
# Checking Sylvie Loeillet
# Checking Johnny Depp
# Checking Patricia Cornwell
# Checking Issa Doumbia
# Checking Elizabeth Hurley
# Checking Jeanne Tripplehorn
# Checking Vincent Perez
# Checking François Morel
# Checking France Dougnac
# Checking Alexandra Stewart
# Checking Philip Mountbatten
# Checking Shia LaBeouf
# Checking Joshua Jackson
# Checking  Magloire
# Checking Peter Dinklage
# Checking Jean Alesi
# Checking Abbey Lee Kershaw
# Checking Adriana Lima
# Checking Jean-François Kahn
# Checking Isabelle Candelier
# Checking Mary-Kate Olsen
# Checking Ashley Olsen
# Checking Éric Berger
# Checking Bruno Counard
# Checking Tim Allen
# Checking Ban Ki-moon
# Checking  Christo
# Checking Joy Esther
# Checking Louis Garrel
# Checking Steffi Graf
# Checking Yasmine Bleeth
# Checking Hana Laszlo
# Checking Cédric Pioline
# Checking Nicole Belloubet
# Checking James Belushi
# Checking Xi Jinping
# Checking Brigitte Fossey
# Checking Michèle Cotta
# Checking Claude Brasseur
# Checking Guy Bedos
# Checking Laurence Badie
# Checking Daniel Brühl
# Checking  Jairo
# Checking Annie Cordy
# Checking Venus Williams
# Checking Greg Kinnear
# Checking  Lio
# Checking Denis Lavant
# Checking Francis Ginibre
# Checking Grace de Capitani
# Checking Étienne Chatiliez
# Checking Fabienne Thibeault
# Checking Marc Jolivet
# Checking Eddy Merckx
# Checking Jean-Luc Moreau
# Checking Ken Loach
# Checking Peter Lupus
# Checking Yvon Gattaz
# Checking Julie Depardieu
# Checking Jeff Mills
# Checking Christian Vadim
# Checking Laurent Grévill
# Checking Julie Arnold
# Checking Linda Thorson
# Checking Nick Tate
# Checking Roger Lemerre
# Checking  Michou
# Checking Robin Tunney
# Checking Laurent Gamelon
# Checking Philippe Manœuvre
# Checking Kathleen Turner
# Checking Jérôme Cahuzac
# Checking Salman Rushdie
# Checking  Aung San Suu Kyi
# Checking Chico Buarque
# Checking Gena Rowlands
# Checking  Amir
# Checking Marie Guillard
# Checking Éric Lartigau
# Checking Caroline Diament
# Checking Catherine Ceylac
# Checking John Goodman
# Checking Stephen Frears
# Checking William de Cambridge
# Checking Yang Liwei
# Checking Doug Savant
# Checking Michel Platini
# Checking Jean-Pierre Mader
# Checking Gérard Lanvin
# Checking Bernie Kopell
# Checking Lalo Schifrin
# Checking Emmanuel-Philibert de Savoie
# Checking Véronika Loubry
# Checking Emmanuelle Seigner
# Checking Jimmy Somerville
# Checking Jacques Bonnaffé
# Checking François Hadji-Lazaro
# Checking  Laroche Valmont
# Checking Lindsay Wagner
# Checking Gilles Jacob
# Checking Patrick Vieira
# Checking Charlotte Le Grix de La Salle
# Checking Selma Blair
# Checking Achinoam Nini
# Checking Frances McDormand
# Checking Jean Tigana
# Checking Michèle Mouton
# Checking Lionel Messi
# Checking Glenn Medeiros
# Checking Florence Thomassin
# Checking Nancy Allen
# Checking Jeff Beck
# Checking Brigitte Fontaine
# Checking Cécile Cassel
# Checking Vladimir Kramnik
# Checking Pierre-François Martin-Laval
# Checking Erica Gimpel
# Checking Charlotte Kady
# Checking Christine Albanel
# Checking Robert Charlebois
# Checking Samuel Benchetrit
# Checking Dany Boon
# Checking Greg LeMond
# Checking Véronique Genest
# Checking Rachid Arhab
# Checking Maxime Bossis
# Checking Gilberto Gil
# Checking Yassine Belattar
# Checking Tobey Maguire
# Checking  J. J. Abrams
# Checking Franck Pitiot
# Checking Marie Sara
# Checking Fabien Barthez
# Checking Gil Bellows
# Checking Félix Gray
# Checking Kathy Bates
# Checking Anny Duperey
# Checking Christine Deviers-Joncour
# Checking Jean-Paul Loth
# Checking Mel Brooks
# Checking Guy Lecluyse
# Checking Claude Évin
# Checking Fred Grandy
# Checking Jacques Toubon
# Checking Colette Castel
# Checking Jacques Balutin
# Checking Vahina Giocante
# Checking Patrick Baud
# Checking Florence Pernel
# Checking Philippe Duquesne
# Checking Rupert Graves
# Checking Vincent D'Onofrio
# Checking Laurent Joffrin
# Checking Alain Finkielkraut
# Checking Lea Massari
# Checking Léa Seydoux
# Checking Liv Tyler
# Checking Pamela Anderson
# Checking Sophie Darel
# Checking Leslie Caron
# Checking Olivia de Havilland
# Checking Margot Robbie
# Checking Flavie Flament
# Checking Samy Naceri
# Checking Pierre Lescure
# Checking Vincent Lacoste
# Checking Sebastian Vettel
# Checking Ludivine Sagnier
# Checking Patrick Wilson
# Checking Éric Toledano
# Checking Élie Chouraqui
# Checking Roland Magdane
# Checking Eddy Mitchell
# Checking Victoria Abril
# Checking René Arnoux
# Checking Gina Lollobrigida
# Checking Amélie Mauresmo
# Checking Marie Vincent
# Checking Shirley Knight
# Checking Jean Raspail
# Checking  50 Cent
# Checking Isabelle Boulay
# Checking Geoffrey Rush
# Checking Nathalie Baye
# Checking Shelley Hack
# Checking George W. Bush
# Checking Fred Dryer
# Checking Claude-Michel Schönberg
# Checking Raymond Depardon
# Checking Ned Beatty
# Checking Tenzin Gyatso
# Checking Jean-Pierre Mocky
# Checking Hélène Carrère d'Encausse
# Checking  Aldebert
# Checking Bénédicte Delmas
# Checking Jorja Fox
# Checking Richard Kolinka
# Checking Audrey Crespo-Mara
# Checking Billy Crudup
# Checking Claude François junior
# Checking Philippe Vasseur
# Checking Jacques Martineau
# Checking Andrew Fletcher
# Checking Jean-Philippe Écoffey
# Checking Kevin Bacon
# Checking Michel Charasse
# Checking Amélie Nothomb
# Checking Courtney Love
# Checking Bernie Bonvoisin
# Checking Chris Cooper
# Checking  O. J. Simpson
# Checking Brian Dennehy
# Checking Pierre Perret
# Checking Sofía Vergara
# Checking Sue Lyon
# Checking Jean-Marie Poiré
# Checking Marcel Azzola
# Update on Marcel Azzola
# Checking Yoann Gourcuff
# Checking Im Soo-jeong
# Checking Justin Chambers
# Checking Cheb Mami
# Checking Muriel Dacq
# Checking Jafar Panahi
# Checking Robin Renucci
# Checking Évelyne Leclercq
# Checking Michèle Barzach
# Checking Patrick Puydebat
# Checking Éric Galliano
# Checking Corynne Charby
# Checking Liz Mitchell
# Checking Lionel Jospin
# Checking Bill Cosby
# Checking Liu Xiang
# Checking Bruno Salomone
# Checking Sylvain Mirouf
# Checking Catherine Breillat
# Checking Harrison Ford
# Checking Jacques Perrin
# Checking Hubert Reeves
# Checking Victoria de Suède
# Checking Jean-Luc Couchard
# Checking Valérie Pécresse
# Checking Matthew Fox
# Checking  Dorothée
# Checking Xavier Darcos
# Checking David Mora
# Checking Diane Kruger
# Checking Brian Austin Green
# Checking Irène Jacob
# Checking Forest Whitaker
# Checking Vincent Lindon
# Checking Terry O'Quinn
# Checking Anne Sinclair
# Checking Christophe Rocancourt
# Checking Michel Desjoyeaux
# Checking Miguel Indurain
# Checking Phoebe Cates
# Checking Marc Esposito
# Checking Mélanie Thierry
# Checking Elena Anaya
# Checking Molly Parker
# Checking Michel Field
# Checking David Hasselhoff
# Checking Camilla Parker Bowles
# Checking Jean-Claude Bourret
# Checking Donald Sutherland
# Checking Mélissa Theuriau
# Checking Kelly Reilly
# Checking Elsa Pataky
# Checking  La Grande Sophie
# Checking Vin Diesel
# Checking Patrick Zard
# Checking James Brolin
# Checking Paul Verhoeven
# Checking Bernard Pons
# Checking Saïd Taghmaoui
# Checking Anthony Edwards
# Checking Karen Cheryl
# Checking Daniel Vaillant
# Checking Ilie Năstase
# Checking Charles Villeneuve
# Checking Anaïs Baydemir
# Checking Omar Epps
# Checking  Indra
# Checking Laurent Lucas
# Checking Rochelle Redfield
# Checking Kim Carnes
# Checking Olivier de Kersauson
# Checking Diana Rigg
# Checking Jacques Delors
# Checking Aurélien Enthoven
# Checking Josh Hartnett
# Checking Sarah Biasini
# Checking Caroline Tresca
# Checking Fabienne Égal
# Checking Arlette Chabot
# Checking Jean-Baptiste Mondino
# Checking Hubert-Félix Thiéfaine
# Checking Selena Gomez
# Checking Jonathan Zaccaï
# Checking Rhys Ifans
# Checking Sophie Le Saint
# Checking John Leguizamo
# Checking Willem Dafoe
# Checking Danny Glover
# Checking Mireille Mathieu
# Checking Paul-Loup Sulitzer
# Checking Claude Villers
# Checking Daniel Radcliffe
# Checking Paul Wesley
# Checking  Armelle
# Checking Stéphane Diagana
# Checking François Bureloup
# Checking Stephanie Seymour
# Checking  Slash
# Checking Eriq La Salle
# Checking Martin L. Gore
# Checking Claude Barzotti
# Checking Larry Manetti
# Checking Sergio Mattarella
# Checking Ronny Cox
# Checking Summer Glau
# Checking Thierry Frémont
# Checking Guy Savoy
# Checking Gus Van Sant
# Checking Lynda Carter
# Checking Yves Duteil
# Checking Hervé Vilard
# Checking Claude Sarraute
# Checking  Diam's
# Checking Véronique Mounier
# Checking Éric Judor
# Checking Lynda Lemay
# Checking Illeana Douglas
# Checking Pierre Sled
# Checking Jacques Legros
# Checking Rita Marley
# Checking Claude Zidi
# Checking Alice Taglioni
# Checking Frédéric Diefenthal
# Checking Jason Statham
# Checking Sandra Bullock
# Checking Roger Taylor
# Checking Nicole Notat
# Checking Helen Mirren
# Checking Grégoire Colin
# Checking Laurent Bignolas
# Checking Isabelle Aubret
# Checking Anne-Élisabeth Blateau
# Checking Manuela Lopez
# Checking Sébastien Courivaud
# Checking Francis Veber
# Checking Anne-Élisabeth Lemoine
# Checking Alexandra Paul
# Checking Jean-Hugues Anglade
# Checking Jean-Luc Ettori
# Checking Jean-Paul Huchon
# Checking David Warner
# Checking  Orlando
# Checking Clotilde Hesme
# Checking Christopher Nolan
# Checking Simon Baker
# Checking Laurence Fishburne
# Checking Kate Bush
# Checking Richard Burgi
# Checking Axelle Abbadie
# Checking Béatrice Agenin
# Checking Jean Reno
# Checking Paul Anka
# Checking Daniel Hechter
# Checking Hervé de Charette
# Checking Ben Chaplin
# Checking Dean Cain
# Checking  J. K. Rowling
# Checking Wesley Snipes
# Checking Paul Duchesnay
# Checking Manuel Gélin
# Checking Michael Biehn
# Checking Jakie Quartz
# Checking Penelope Fillon
# Checking Noëlle Perna
# Checking  Stone
# Checking Hubert Védrine
# Checking Geraldine Chaplin
# Checking Mouloud Achour
# Checking Eduardo Noriega
# Checking Demián Bichir
# Checking Mac Lesggy
# Checking Évelyne Dress
# Checking Nathalie Delon
# Checking Yaniss Lespert
# Checking Laura Tanguy
# Checking Edward Furlong
# Checking Mary-Louise Parker
# Checking Urbain Cancelier
# Checking Alain Giresse
# Checking Charlotte Casiraghi
# Checking Thierry Neuvic
# Checking Mathieu Kassovitz
# Checking Vincent Perrot
# Checking James Hetfield
# Checking Lambert Wilson
# Checking John Landis
# Checking Martin Sheen
# Checking Meghan Markle
# Checking Emmanuelle Boidron
# Checking Laurent Luyat
# Checking Pascal Nègre
# Checking José Luis Rodríguez Zapatero
# Checking François Valéry
# Checking Klaus Schulze
# Checking Emmanuel Chain
# Checking Patrick Cohen
# Checking Isabel Otero
# Checking Carole Laure
# Checking Élisabeth Depardieu
# Checking John Saxon
# Checking  M. Night Shyamalan
# Checking Luc Alphand
# Checking Stepfanie Kramer
# Checking Bruce Dickinson
# Checking Caroline Cellier
# Checking Pascal Duquenne
# Checking Bernard Ménez
# Checking Dustin Hoffman
# Checking Audrey Tautou
# Checking Jacques-Antoine Granjon
# Checking David Martin
# Checking Edgar Givry
# Checking  Anémone
# Checking Sam Elliott
# Checking Bulle Ogier
# Checking Romano Prodi
# Checking Pierre Santini
# Checking Yves Coppens
# Checking Devon Aoki
# Checking Chris Hemsworth
# Checking Grégoire Ludig
# Checking Djamel Bouras
# Checking Anna Gunn
# Checking Valérie Stroh
# Checking Joe Jackson
# Checking Hulk Hogan
# Checking Georges Pernoud
# Checking Patrick Bouchitey
# Checking Dominique Perben
# Checking Roland Cayrol
# Checking Casey Affleck
# Checking Pete Sampras
# Checking Peter Krause
# Checking Thierry Desroses
# Checking Isaac de Bankolé
# Checking  Kid Creole
# Checking Jean Nouvel
# Checking Jean-Pierre Talbot
# Checking George Hamilton
# Checking Georges Kiejman
# Checking Alex Goude
# Checking Manu Joucla
# Checking Kōji Kondō
# Checking Romane Bohringer
# Checking Emmanuelle Béart
# Checking Lolita Lempicka
# Checking Jean-Christophe Cambadélis
# Checking Antonio Fargas
# Checking Steve Martin
# Checking Wim Wenders
# Checking Roger Carel
# Checking Jennifer Lawrence
# Checking Frédéric Nihous
# Checking Anne du Royaume-Uni
# Checking Sylvie Vartan
# Checking Laura Innes
# Checking James Cameron
# Checking Patrick Balkany
# Checking Pierre Richard
# Checking Hervé Morin
# Checking Stephan Eicher
# Checking Sean Penn
# Checking Guilaine Chenu
# Checking Nelson Piquet
# Checking Guillermo Vilas
# Checking Allain Bougrain-Dubourg
# Checking Robert De Niro
# Checking Michel Creton
# Checking Pierre Douglas
# Checking Jean-Jacques Sempé
# Checking  Aphex Twin
# Checking Alexandre Pesle
# Checking Noam Kaniel
# Checking Daniela Lumbroso
# Checking Didier Auriol
# Checking Madeleine Stowe
# Checking Carole Bouquet
# Checking Sergio Castellitto
# Checking Robert Redford
# Checking Roman Polanski
# Checking Just Fontaine
# Checking Luc Montagnier
# Checking Hugues Aufray
# Checking Maria de Medeiros
# Checking Kevin Dillon
# Checking Valérie Kaprisky
# Checking John Deacon
# Checking Bill Clinton
# Checking Jill St John
# Checking Meghan Ory
# Checking Amy Adams
# Checking Patrick Drahi
# Checking Robert Plant
# Checking  Fabrice
# Checking Massimo Gargia
# Checking Jean-Loup Chrétien
# Checking Louis Mermaz
# Checking Alain Goraguer
# Checking Cody Kasch
# Checking Usain Bolt
# Checking Kimberly Stewart
# Checking Sergey Brin
# Checking Mohammed VI
# Checking Laura Morante
# Checking Patrick Juvet
# Checking Philippe Magnan
# Checking Frédéric Mitterrand
# Checking Patrice Laffont
# Checking François Pinault
# Checking Laurent Lafitte
# Checking Mats Wilander
# Checking Micheline Presle
# Checking Scott Caan
# Checking Sylvain Durif
# Checking Park Chan-wook
# Checking Alexandre Desplat
# Checking Dominique Frot
# Checking Jacques Weber
# Checking Vera Miles
# Checking Roland Dumas
# Checking Rupert Grint
# Checking Alex Lutz
# Checking Dave Chappelle
# Checking Stephen Fry
# Checking Jean-Michel Jarre
# Checking James Whitmore Jr.
# Checking Rachel Bilson
# Checking  Ovidie
# Checking Claudia Schiffer
# Checking Tim Burton
# Checking John Savage
# Checking Tom Skerritt
# Checking Sean Connery
# Checking Jeannette Bougrab
# Checking Daniel Lévi
# Checking Brett Cullen
# Checking Patrick Devedjian
# Checking Gwendoline Hamon
# Checking Chandra Wilson
# Checking Arno Klarsfeld
# Checking Gustave Kervern
# Checking Jean-Yves Berteloot
# Checking Peter Stormare
# Checking Philippe Labro
# Checking David Fincher
# Checking David Soul
# Checking Kyan Khojandi
# Checking Émilie Dequenne
# Checking John Hensley
# Checking  Enzo Enzo
# Checking Rebecca De Mornay
# Checking Temple Grandin
# Checking Jean Ragnotti
# Checking Joel Schumacher
# Checking Elliott Gould
# Checking Loana Petrucciani
# Checking Valérie Bénaïm
# Checking Yves Calvi
# Checking Benoît Delépine
# Checking Jean-Claude Killy
# Checking Michel Chevalet
# Checking Geneviève de Fontenay
# Checking Vincent Delerm
# Checking Sophie Quinton
# Checking Rania al-Yassin
# Checking Éric Zemmour
# Checking Serge Blanco
# Checking Timothy Bottoms
# Checking Richard Gere
# Checking Bill Kaulitz
# Checking Jean Sarkozy
# Checking  Lââm
# Checking Ricardo Antonio Chavira
# Checking Virgile Bayle
# Checking Cris Campion
# Checking Barry Gibb
# Checking Keanu Reeves
# Checking Pascal Demolon
# Checking Jimmy Connors
# Checking Mark Harmon
# Checking Catherine Lachens
# Checking Thibaud Vaneck
# Checking Marie Chevalier
# Checking Muriel Hermine
# Checking Jean-Pierre Jeunet
# Checking Éva Darlan
# Checking Mario Draghi
# Checking Macha Méril
# Checking Zine el-Abidine Ben Ali
# Checking Pierre Troisgros
# Checking Irène Papas
# Checking Charlotte Le Bon
# Checking Wes Bentley
# Checking Moundir Zoughari
# Checking Louis Aliot
# Checking Natacha Amal
# Checking Yann Queffélec
# Checking Axel Lattuada
# Checking Philippe Dana
# Checking Chantal Thomass
# Checking Gérard d'Aboville
# Checking Denise Fabre
# Checking Raquel Welch
# Checking George Lazenby
# Checking William Devane
# Checking Annick Alane
# Checking Stéphane Guivarc'h
# Checking Sören Prévost
# Checking Jane Curtin
# Checking Gō Nagai
# Checking Jean-Claude Gayssot
# Checking Roger Waters
# Checking Evan Rachel Wood
# Checking Matthieu Gonet
# Checking Cécile Siméone
# Checking  Pierpoljak
# Checking Mira Furlan
# Checking Julie Leclerc
# Checking Henri Sannier
# Checking Abdou Diouf
# Checking Martin Freeman
# Checking Heather Thomas
# Checking Pascal Greggory
# Checking Jean-Michel Larqué
# Checking Loup-Denis Elion
# Checking Goran Višnjić
# Checking Henry Thomas
# Checking Michel Muller
# Checking Pascal Praud
# Checking Hugh Grant
# Checking Éric Serra
# Checking Dani Lary
# Checking Dave Stewart
# Checking Tom Wopat
# Checking Hélène Vincent
# Checking Gustavo Kuerten
# Checking Colin Firth
# Checking Mireille Dumas
# Checking Amy Irving
# Checking Bachar el-Assad
# Checking Serge Hazanavicius
# Checking Brian De Palma
# Checking Jacques Gaillot
# Checking Marwa Loud
# Checking Mylène Farmer
# Checking Jocelyne Béroard
# Checking Joe Pantoliano
# Checking Milo Manara
# Checking Joëlle Goron
# Checking Michel Drucker
# Checking Guy Gilbert
# Checking Ian Holm
# Checking Patricia Spehar
# Checking Christine Arron
# Checking Goran Ivanišević
# Checking Emma Sjöberg
# Checking Michael Johnson
# Checking Alain Ducasse
# Checking Noël Godin
# Checking Jacqueline Bisset
# Checking Andrew Lincoln
# Checking  Nas
# Checking Morten Harket
# Checking Sam Neill
# Checking Henry de Sussex
# Checking Caterina Murino
# Checking Letizia Ortiz
# Checking Tommy Lee Jones
# Checking Carmen Maura
# Checking Pierre Bonte
# Checking Henry Silva
# Checking Rossy de Palma
# Checking Laurent Fontaine
# Checking  Art Mengo
# Checking Mickey Rourke
# Checking George Chakiris
# Checking Stéphane Rousseau
# Checking Franck Piccard
# Checking Jérôme Bonaldi
# Checking Serge Klarsfeld
# Checking Jean-Claude Carrière
# Checking Théo Fernandez
# Checking Chloé Mortaud
# Checking Lynda Lacoste
# Checking Sabine Paturel
# Checking Alessandra Martines
# Checking Alexandra Vandernoot
# Checking Thierry Marx
# Checking Bruno Todeschini
# Checking Seymour Brussel
# Checking Ann Zacharias
# Checking Marie-Anne Chazel
# Checking  Twiggy
# Checking Jeremy Irons
# Checking Alain Lipietz
# Checking David McCallum
# Checking Jacques Calvet
# Checking Brian Joubert
# Checking Maggie Cheung
# Checking Cyril Neveu
# Checking Sabine Azéma
# Checking Sophia Loren
# Checking Veronica Antico
# Checking Olivia Bonamy
# Checking Anne Depétrini
# Checking Frédéric Beigbeder
# Checking Ethan Coen
# Checking François Cluzet
# Checking Bill Murray
# Checking Stephen King
# Checking  Ronaldo
# Checking Anthony Dupray
# Checking François-Xavier Demaison
# Checking Emmanuel Petit
# Checking Benoît Poelvoorde
# Checking Shari Belafonte
# Checking Anna Karina
# Checking Damien Jouillerot
# Checking Bruno Solo
# Checking Catherine Benguigui
# Checking Chi McBride
# Checking Sam Karmann
# Checking Guillaume Durand
# Checking Patrick Simpson-Jones
# Checking Jean-Luc Azoulay
# Checking Julio Iglesias
# Checking Michel Temer
# Checking Eugène Saccomano
# Checking Katja Kassin
# Checking Marie-Christine Adam
# Checking Claire Borotra
# Checking Catherine Zeta-Jones
# Checking Will Smith
# Checking Tate Donovan
# Checking  Juliette
# Checking Heather Locklear
# Checking Michael Madsen
# Checking Karl-Heinz Rummenigge
# Checking Patrick Braoudé
# Checking Bernard Le Coq
# Checking Philippe Peythieu
# Checking Pedro Almodóvar
# Checking Anson Williams
# Checking Firmine Richard
# Checking Michael Douglas
# Checking Gilles Schneider
# Checking Henri Pescarolo
# Checking Jean Sorel
# Checking Nino Cerruti
# Checking Valérie Bègue
# Checking Cindy Fabre
# Checking Thierry Dugeon
# Checking Melissa Sue Anderson
# Checking Philippe Lavil
# Checking Margot Abascal
# Checking Roschdy Zem
# Checking Cécilia Hornus
# Checking Jacques Chambon
# Checking Jean-Marc Barr
# Checking Christophe Bourseiller
# Checking  A Martinez
# Checking Jean-Loup Dabadie
# Checking Isabelle Brès
# Checking Emmanuelle Gaume
# Checking Naomi Watts
# Checking Carole Richert
# Checking Nathalie Rihouet
# Checking Tatiana de Rosnay
# Checking Stéphane Marie
# Checking Marielle Goitschel
# Checking Anaïs Demoustier
# Checking Roger Bart
# Checking Philippe Caroit
# Checking Michelle Bachelet
# Checking Lech Wałęsa
# Checking Yves Rénier
# Checking Jean-Pierre Elkabbach
# Checking Jerry Lee Lewis
# Checking Mylène Demongeot
# Checking Marion Cotillard
# Checking Thomas Jouannet
# Checking Alexis Trégarot
# Checking Monica Bellucci
# Checking Anthony Delon
# Checking  Raël
# Checking Diane Dufresne
# Checking Jean-Louis Debré
# Checking Angie Dickinson
# Checking Jules-Édouard Moustic
# Checking Jeane Manson
# Checking Jean-Pierre Castaldi
# Checking  Dani
# Checking Jean-Luc Bideau
# Checking Stella Stevens
# Checking Julie Andrews
# Checking Jimmy Carter
# Checking Maxime Godart
# Checking Pierre Mathieu
# Checking Frank Delay
# Checking Emma Colberti
# Checking Alexandra Kazan
# Checking Luis Fernandez
# Checking Alicia Vikander
# Checking Mickaël Vendetta
# Checking Shannyn Sossamon
# Checking Seann William Scott
# Checking Neve Campbell
# Checking Nathalie Vincent
# Checking Clive Owen
# Checking Tommy Lee
# Checking Lou Bohringer
# Checking Sara Forestier
# Checking Christoph Waltz
# Checking Tchéky Karyo
# Checking Jesse Eisenberg
# Checking Kate Winslet
# Checking Sophie Dudemaine
# Checking Sophie Favier
# Checking Daniel Baldwin
# Checking Caroline Loeb
# Checking Karen Allen
# Checking Brian Johnson
# Checking Marie Laforêt
# Checking Mélody Vilbert
# Checking Jeremy Sisto
# Checking Lola Dueñas
# Checking Sophie Duez
# Checking Nathalie Nell
# Checking Nicolas Peyrac
# Checking Josée Dayan
# Checking Britt Ekland
# Checking Valérie Maurice
# Checking Viktor Lazlo
# Checking Vladimir Poutine
# Checking Enki Bilal
# Checking Bernard Lavilliers
# Checking Desmond Tutu
# Checking Bella Thorne
# Checking Juliette Chêne
# Checking Martin Henderson
# Checking Matt Damon
# Checking Jeremy Davies
# Checking Peter Greene
# Checking François Pérusse
# Checking Stephanie Zimbalist
# Checking Sigourney Weaver
# Checking Jean-Jacques Beineix
# Checking Chevy Chase
# Checking Jesse Jackson
# Checking Paul Hogan
# Checking Jean-Claude Gaudin
# Checking Yann Barthès
# Checking Laurent Mariotte
# Checking  Sanseverino
# Checking Marina Carrère d'Encausse
# Checking Michael Paré
# Checking Tony Shalhoub
# Checking Pierre Jolivet
# Checking Nicole Croisille
# Checking Brian Blessed
# Checking Didier Roustan
# Checking Hippolyte Girardot
# Checking Ariane Ascaride
# Checking Francis Perrin
# Checking Christian Dingler
# Checking Ben Vereen
# Checking Charles Dance
# Checking Peter Coyote
# Checking Arlette Didier
# Checking Lætitia Larusso
# Checking Takeshi Kaneshiro
# Checking Luke Perry
# Checking David Morse
# Checking Jean-Jacques Goldman
# Checking John Nettles
# Checking Flore Bonaventura
# Checking  Tonton David
# Checking Patrick Bosso
# Checking François Levantal
# Checking Clémentine Célarié
# Checking Brigitte Lahaie
# Checking Sacha Baron Cohen
# Checking Nancy Kerrigan
# Checking Arnaud Gidoin
# Checking Philippe Torreton
# Checking Éric Blanc
# Checking Isabelle Gélinas
# Checking Kelly Preston
# Checking Arturo Brachetti
# Checking  Christophe
# Checking Paul Simon
# Checking Sami Frey
# Checking Nana Mouskouri
# Checking Tania Young
# Checking Gérald de Palmas
# Checking Bruno Masure
# Checking Christian Bujeau
# Checking Udo Kier
# Checking Cliff Richard
# Checking Elena Dementieva
# Checking Mathieu Demy
# Checking Didier Deschamps
# Checking Sarah Ferguson
# Checking Tanya Roberts
# Checking Michel Aumont
# Checking Frédéric Michalak
# Checking Rachid Badouri
# Checking Marius Colucci
# Checking Elsa Zylberstein
# Checking Marc Levy
# Checking Tim Robbins
# Checking Carmen Sevilla
# Checking Angela Lansbury
# Checking Agathe Auproux
# Checking Marion Rolland
# Checking Benjamin Bove
# Checking Kimi Räikkönen
# Checking Matthew Macfadyen
# Checking Ziggy Marley
# Checking Nathalie Tauziat
# Checking Henri Giscard d'Estaing
# Checking Thierry Amiel
# Checking Emmanuelle Laborit
# Checking Guillaume de Tonquédec
# Checking Bruno Lochet
# Checking Martina Navrátilová
# Checking Isabelle Autissier
# Checking Guy Roux
# Checking Roger Cross
# Checking Agnès Jaoui
# Checking Thierry Beccaro
# Checking Sabine Haudepin
# Checking Robert Hue
# Checking John Lithgow
# Checking Michael Gambon
# Checking  Snoop Dogg
# Checking Dannii Minogue
# Checking Frédérique Courtadon
# Checking Sonia Dubois
# Checking Viggo Mortensen
# Checking Danny Boyle
# Checking Marc Toesca
# Checking Claude Sérillon
# Checking André Santini
# Checking Daniel Prévost
# Checking  Max
# Checking Ken Watanabe
# Checking Benyamin Netanyahou
# Checking Pascale Roberts
# Checking Valeria Golino
# Checking Lionel Abelanski
# Checking Bob Odenkirk
# Checking Philippe Decouflé
# Checking Jeff Goldblum
# Checking Catherine Deneuve
# Checking Christopher Lloyd
# Checking Ryan Reynolds
# Checking Jil Caplan
# Checking  Weird Al Yankovic
# Checking Paul Kagame
# Checking Ang Lee
# Checking Philippe Poupon
# Checking Arielle Boulin-Prat
# Checking  Pelé
# Checking Marthe Mercadier
# Checking  Drake
# Checking Florian Philippot
# Checking Jemima Rooper
# Checking Thierry Adam
# Checking Kevin Kline
# Checking  F. Murray Abraham
# Checking Elena Lenina
# Checking Mathieu Amalric
# Checking Nilda Fernández
# Checking Glynis Barber
# Checking Marion Ross
# Checking Joël Cantona
# Checking Cary Elwes
# Checking Evo Morales
# Checking Gilbert Rozon
# Checking Lauren Tewes
# Checking Patrice Carmouze
# Checking Hillary Clinton
# Checking Catherine Barma
# Checking  Litzy
# Checking Lorànt Deutsch
# Checking Alain Boghossian
# Checking Vincent Mc Doom
# Checking Caroline Avon
# Checking Manu Katché
# Checking Roberto Benigni
# Checking Jean Schultheis
# Checking John Cleese
# Checking Gilles Vigneault
# Checking Jérémy Michalak
# Checking Joaquin Phoenix
# Checking Ben Harper
# Checking Julia Roberts
# Checking Gilles Gaston-Dreyfus
# Checking Isabelle Giordano
# Checking Eros Ramazzotti
# Checking Mahmoud Ahmadinejad
# Checking Didier Bénureau
# Checking Dennis Franz
# Checking Olivier Mazerolle
# Checking Bernie Ecclestone
# Checking Cecilie Thomsen
# Checking Robert Pirès
# Checking Winona Ryder
# Checking Christophe Alévêque
# Checking Franck de Lapersonne
# Checking Anne Alvaro
# Checking Kate Jackson
# Checking Coline Serreau
# Checking Richard Dreyfuss
# Checking Gérard Klein
# Checking Thomas N'Gijol
# Checking Astrid Veillon
# Checking Diego Maradona
# Checking Vincent Lagaf'
# Checking Zabou Breitman
# Checking Henry Winkler
# Checking Jean-Pierre Kalfon
# Checking Céline Balitran
# Checking Dermot Mulroney
# Checking André Lamy
# Checking Peter Jackson
# Checking Jeannie Longo
# Checking Mario Ramsamy
# Checking Lionnel Astier
# Checking Ron Rifkin
# Checking Judith El Zein
# Checking Thierry Moreau
# Checking Valeria Cavalli
# Checking Rachel Ticotin
# Checking Salvatore Adamo
# Checking Bernard Kouchner
# Checking Benoît Chaigneau
# Checking Samuel Le Bihan
# Checking Stefanie Powers
# Checking Dalil Boubakeur
# Checking Julia Channel
# Checking Dolph Lundgren
# Checking Kate Capshaw
# Checking Michel Boujenah
# Checking Ariane Carletti
# Checking Marlène Jobert
# Checking Famke Janssen
# Checking Muriel Hees
# Checking Charles Biétry
# Checking Art Garfunkel
# Checking Harris Yulin
# Checking Emma Stone
# Checking Ethan Hawke
# Checking Laurene Powell Jobs
# Checking Lori Singer
# Checking Jacques Charrier
# Checking Michel Bouquet
# Checking  Raphael (chanteur)
# Checking Kim Yoon-jin
# Checking Michel Roth
# Checking Florence Foresti
# Checking Esther Kooiman
# Checking Tom Novembre
# Checking Alfre Woodard
# Checking Alexandra Gentil
# Checking Jennifer Ayache
# Checking Giovanna Mezzogiorno
# Checking Joëlle Ursull
# Checking Lou Ferrigno
# Checking Ben l'Oncle Soul
# Checking Ennio Morricone
# Checking Jérôme Anthony
# Checking Calista Flockhart
# Checking Stanley Tucci
# Checking Nadine Trintignant
# Checking Anne Hathaway
# Checking Tonya Harding
# Checking Nadia Comăneci
# Checking Gilbert Melki
# Checking Patrick Sabatier
# Checking Patrice Leconte
# Checking  Piem
# Checking Michel Robin
# Checking Julie Caignault
# Checking Antoine Duléry
# Checking Olivier Marchal
# Checking Bernard Hinault
# Checking Charles de Galles
# Checking Agathe Natanson
# Checking Jean-Claude Petit
# Checking Henry Chapier
# Update on Henry Chapier
# Checking Laura Smet
# Checking Virginie Ledoyen
# Checking Jonny Lee Miller
# Checking Beverly D'Angelo
# Checking Anni-Frid Lyngstad
# Checking Bob Gunton
# Checking Sam Waterston
# Checking Yaphet Kotto
# Checking Petula Clark
# Checking Edward Asner
# Checking Thomas Fabius
# Checking Aleksandr Popov
# Checking Lisa Bonet
# Checking Shigeru Miyamoto
# Checking Jacky Nercessian
# Checking Eunice Barber
# Checking Maureen Dor
# Checking Dylan Walsh
# Checking Gilles Détroit
# Checking Mary Elizabeth Mastrantonio
# Checking Michel Lagueyrie
# Checking Lauren Hutton
# Checking Owen Wilson
# Checking Caroline Proust
# Checking Jameson Parker
# Checking Linda Evans
# Checking Alain Barrière
# Checking Sarah Stern
# Checking Daria Werbowy
# Checking Laurent Blanc
# Checking Jodie Foster
# Checking Patrick de Carolis
# Checking Hervé Claude
# Checking Jean-François Cayrey
# Checking Sean Young
# Checking Barbara Hendricks
# Checking Richard Masur
# Checking Philippe Ogouz
# Checking Judith Magre
# Checking Inés Sastre
# Checking Cherry Jones
# Checking Scarlett Johansson
# Checking Isild Le Besco
# Checking Mélanie Doutey
# Checking Marjane Satrapi
# Checking Anne Brochet
# Checking Stéphane Freiss
# Checking Basile de Koch
# Checking Isabelle Bouysse
# Checking Vincent Cassel
# Checking Francis Cabrel
# Checking Chantal Nobel
# Checking Isabelle Renauld
# Checking Thierry Samitier
# Checking Alain Chabat
# Checking Emir Kusturica
# Checking Dwight Schultz
# Checking Gaspard Ulliel
# Checking Marcy Walker
# Checking Karin Schubert
# Checking Robert Marchand
# Checking Michael Vartan
# Checking Daniel Ducruet
# Checking William Fichtner
# Checking Philippe Delerm
# Checking Jean-Pierre Dionnet
# Checking Aimé Jacquet
# Checking Aldo Maccione
# Checking Mary Elizabeth Winstead
# Checking John Galliano
# Checking Ed Harris
# Checking Jean-Charles de Castelbajac
# Checking Pierre Joxe
# Checking Denis Maréchal
# Checking Don Cheadle
# Checking Sophie Artur
# Checking Joel Coen
# Checking Tonie Marshall
# Checking Jacques Chirac
# Checking Pierre Sarkozy
# Checking Aurélien Portehaut
# Checking Virginie Guilhaume
# Checking Didier Cauchy
# Checking Micky Sébastian
# Checking Gordon Liu Chia-hui
# Checking Sophie Guillemin
# Checking David Strajmayster
# Checking Charlene Tilton
# Checking Cyrielle Clair
# Checking Pierre Arditi
# Checking Daniel Pennac
# Checking Woody Allen
# Checking Charles Gérard
# Checking Amaury Leveaux
# Checking Arthur Jugnot
# Checking Yvonne Catterfeld
# Checking Adel Kachermi
# Checking Monica Seles
# Checking Fabien Lecœuvre
# Checking Steven Bauer
# Checking  Angèle
# Checking Vaimalama Chaves
# Checking Sébastien Roch
# Checking Brendan Fraser
# Checking Steven Culp
# Checking Melody Anderson
# Checking Diane Kurys
# Checking Joop Zoetemelk
# Checking Nicolas Coster
# Checking Jean-Luc Godard
# Checking  Jay Z
# Checking Sergueï Bubka
# Checking Christian Jacob
# Checking Jean-Pierre Darroussin
# Checking Corinne Marchand
# Checking Vincent Claude
# Checking Annie Pujol
# Checking Jean-Luc Petitrenaud
# Checking Jeroen Krabbé
# Checking  Little Richard
# Checking Jacques Dessange
# Checking Stormi Henley
# Checking Arnaud Ducret
# Checking Aurélie Bargème
# Checking Claude Chirac
# Checking Tom Hulce
# Checking Patrick Bauchau
# Checking Philippe Bouvard
# Checking Emily Browning
# Checking Fabien Pelous
# Checking Abdellatif Kechiche
# Checking Georges Corraface
# Checking Jean-Claude Casadesus
# Checking Marion Jollès
# Checking Dominic Monaghan
# Checking Camille Raymond
# Checking Philippe Katerine
# Checking Chantal Gallia
# Checking Didier Pain
# Checking Gérard Holtz
# Checking Jean-Paul Goude
# Checking Shera Kerienski
# Checking Anna Gavalda
# Checking Laurent Weil
# Checking Emmanuel Carrère
# Checking John Malkovich
# Checking Jean-Louis Étienne
# Checking Michael Nouri
# Checking Judi Dench
# Checking Kirk Douglas
# Checking Claire Barsacq
# Checking Karim Adda
# Checking Kenneth Branagh
# Checking Catherine Hiegel
# Checking Mos Def
# Checking Michel Courtemanche
# Checking Christine Dejoux
# Checking Enrico Macias
# Checking Jean-Louis Trintignant
# Checking Jennifer Connelly
# Checking Yolande Folliot
# Checking Bill Nighy
# Checking Françoise de Panafieu
# Checking Patrice Duhamel
# Checking Alain Doutey
# Checking Gérard Filippelli
# Checking Manu Dibango
# Checking Dick Van Dyke
# Checking Guillaume Carcaud
# Checking Noémie Elbaz
# Checking Steve Buscemi
# Checking Jean-Marie Messier
# Checking Christopher Plummer
# Checking Valérie Decobert
# Checking Gérard Loussine
# Checking Jane Birkin
# Checking Stan Smith
# Checking Nathalie Courval
# Checking  Zep
# Checking Helen Slater
# Checking Pascal Bruckner
# Checking Jean-Michel Ribes
# Checking Benjamin Bratt
# Checking Maruschka Detmers
# Checking Anne Le Ny
# Checking Catherine Jacob
# Checking Carlo Brandt
# Checking Benny Andersson
# Checking Manny Pacquiao
# Checking Giovanni Ribisi
# Checking Philippe Lefebvre
# Checking Christophe Hondelatte
# Checking Lionel Chamoulaud
# Checking Bill Pullman
# Checking  Édika
# Checking Jean-Claude Drouot
# Checking  François
# Checking Mazarine Pingeot
# Checking Arantxa Sánchez Vicario
# Checking Alexia Laroche-Joubert
# Checking Rachel Griffiths
# Checking Brad Pitt
# Checking Pauline Ester
# Checking Olivier Broche
# Checking Isabelle Duchesnay
# Checking Michel Vuillermoz
# Checking Laurent Voulzy
# Checking Steven Spielberg
# Checking Roger E. Mosley
# Checking Jake Gyllenhaal
# Checking Alberto Tomba
# Checking Béatrice Dalle
# Checking Jean-Patrick Capdevielle
# Checking  Rufus
# Checking André Gaillard
# Checking Nadia Farès
# Checking Édouard Montoute
# Checking Hélène Rollès
# Checking Jenny Agutter
# Checking Bruno Moynot
# Checking Jean-Pierre Descombes
# Checking Claude Pierrard
# Checking Ernest-Antoine Seillière
# Checking Julie Delpy
# Checking Corinne Touzet
# Checking Thierry Mugler
# Checking Greg Germain
# Checking Henri Guybet
# Checking Alicia Alonso
# Checking Jean-Baptiste Maunier
# Checking Manu Payet
# Checking Sergi López
# Checking Ralph Fiennes
# Checking Annie Lemoine
# Checking Anne Magnien
# Checking Philippe Harel
# Checking Estella Warren
# Checking Dave Murray
# Checking  Akihito
# Checking Valérie Payet
# Checking Diane Tell
# Checking Edwige Fenech
# Checking Philippe Nahon
# Checking Mary Higgins Clark
# Checking Anthony Sonigo
# Checking Carole Rousseau
# Checking Helena Christensen
# Checking Íngrid Betancourt
# Checking Sissy Spacek
# Checking Noël Mamère
# Checking Bernard Alane
# Checking François de Closets
# Checking Simone Garnier
# Checking Kit Harington
# Checking Hugo Lloris
# Checking Jérôme Le Banner
# Checking Cécile Bois
# Checking Fabienne Babe
# Checking Phil Spector
# Checking  Régine
# Checking André Lajoinie
# Checking Kristina Pimenova
# Checking Raphaëlle Agogué
# Checking Masi Oka
# Checking Laurent Romejko
# Checking Philippe Lefait
# Checking Paul Personne
# Checking Gérard Depardieu
# Checking Serge July
# Checking John Amos
# Checking Michel Piccoli
# Checking Sienna Miller
# Checking Maggie Smith
# Checking Charles Fiterman
# Checking Jude Law
# Checking Serge Riaboukine
# Checking Jacques Boudet
# Checking Bernard Cribbins
# Checking Jason Kay
# Checking Ben Johnson
# Checking Patti Smith
# Checking Robert Hossein
# Checking Gong Li
# Checking Jean-Pierre Rives
# Checking Barbara Carrera
# Checking Marcel Rufo
# Checking Ben Kingsley
# Checking Anthony Hopkins
# Checking Suzy Delair
# Checking Robert Pine
# Checking Larry Wilcox
# Checking Marie Dauphin
# Checking  Monstre de Frankenstein
# Checking  Rayman
# Checking Pascal Vincent
# Checking Hercule Poirot
# Checking Tommy Haas
# Checking Mathieu Delarive
# Checking Joe Dante
# Checking Jérôme Anger
# Checking Stéphanie de Muru
# Checking Frédéric Zeitoun
# Checking Frédéric Vion
# Checking Frédérick Gersal
# Checking Charlotte Bouteloup
# Checking Charlie Brown
# Checking Charles S. Dutton
# Checking Adriano Celentano
# Checking Mimi Rogers
# Checking  Fozzie
# Checking  Panoramix
# Checking David Strathairn
# Checking Scott Glenn
# Checking Fifi Brindacier
# Checking Tom Sawyer
# Checking Carole Varenne
# Checking Daniel Chenevez
# Checking Marc Caro
# Checking Alice Isaaz
# Checking Bernard Lavalette
# Checking Lilou Fogli
# Checking Bernard Yerlès
# Checking Bernard Thévenet
# Checking Charly Oleg
# Checking Jean Bertho
# Checking Felicity Jones
# Checking  Difool
# Checking Christian Spitz
# Checking Chris Pine
# Checking Philippe Corti
# Checking  Miss Marple
# Checking Sylvain Tesson
# Checking Kevin Mayer
# Checking Shirley Bassey
# Checking Simon Pegg
# Checking Dominique de Lacoste
# Checking Nicole Avezard
# Checking Amancio Ortega Gaona
# Checking Jennifer Lauret
# Checking Dyan Cannon
# Checking Marcel Zanini
# Checking John Paul Young
# Checking Hatsune Miku

# %% [markdown]
# # Manual update
#
# When there is missing celebrities or a mistake, we can fix manully some informations. For exemple there were several celebrities without the twitter account but I knew that they have one so we can add it

# %%
def manual_update(name, twitter):
    conn = sqlite3.connect('F:/data/birthday.db')
    c = conn.cursor()
    c.execute("SELECT * FROM birthday WHERE name = ?", (name,))
    print(c.fetchone())
    c.execute("UPDATE birthday SET twitter = ? WHERE name = ?", (twitter, name))
    conn.commit()
    c.execute("SELECT * FROM birthday WHERE name = ?", (name,))
    print(c.fetchone())
    conn.close()

# %%
# manual_update(" Cartouche", "@cartouche")

# %%
# manual_update("Sandrine Quétier", "@SandQuetierOff")

# %%
# manual_update(" Comte de Bouderbala", "@comtebouderbala")

# %%
# manual_update(" Jul", "@jul")

# %%
# manual_update(" Natoo", "@Nato_o")

# %%
# manual_update("Laurent Baffie", "@lolobababa")

# %%
# manual_update("Alain Bernard", "@alainbernard")

# %%
# manual_update("Florence Parly", "@florence_parly")

# %%
# manual_update("Christian Estrosi", "@cestrosi")

# %%
# manual_update("Bernard Laporte", "@BernardLaporte_")

# %%
# manual_update("Patrick Timsit", "@patricktimsit")

# %%
# manual_update("Vincent Moscato", "@VINCENT_MOSCATO")

# %%
# manual_update("Ève Angeli", "@eveangelioff")

# %%
# add_data("1986-08-30", "Raphaël Carlier", "@Raphael_Carlier", "", "France", "0")

# %%
# add_data("1986-07-07", "David Coscas", "@levraimcfly", "", "France", "0")

# %%
# add_data("1992-08-07", "Damien Laguionie", "@terracid", "", "France", "0")

# %%
# add_data("1992-01-08", "Thomas Iturralde", "@laink", "", "France", "0")

# %% [markdown]
# # Change birthday
#
# Finally, there is maybe wrong date on the website. It was the case with Willy Rovelli. This section is done to update this

# %%
name = "Willy Rovelli"
date = "1980-03-18"

# %%
conn = sqlite3.connect('F:/data/birthday.db')
c = conn.cursor()
c.execute("SELECT * FROM birthday WHERE name = ?", (name,))
print(c.fetchone())
c.execute("UPDATE birthday SET birthday = ? WHERE name = ?", (date, name))
conn.commit()
c.execute("SELECT * FROM birthday WHERE name = ?", (name,))
print(c.fetchone())
conn.close()

# %% [markdown]
# # Check proposition
#
# One improvement I've done is also host a website (simple one) to let people propose new celebrities. I'll try to review taht sometimes and this part is done for that purpose.

# %%
conn = sqlite3.connect('site/databases/proposition.db')
df = pd.read_sql_query("SELECT * FROM birthday", conn)
conn.close()
df.head()
# Out:
# Empty DataFrame
# Columns: [birthday, name, twitter, url, country, dead]
# Index: []

# %%
# conn = sqlite3.connect('site/databases/proposition.db')
# c = conn.cursor()
# c.execute('''DROP TABLE IF EXISTS birthday''')
# c.execute('''CREATE TABLE birthday
#              (birthday date_text, name text, twitter text, url text, country text, dead integer)''')
# conn.commit()
# conn.close()

# %% [markdown]
# # Conclusion
#
# This Notebook is quite simple (and not very clean - a refactoring would be great...) but we saw here how to scrap data from a website and store it in a SQLite database. In the next Notebook, we will quickly explore the data we have.
#
# Regarding the website, it's available @ http://nicolasmine.pythonanywhere.com/.
